# %%
import os
import csv
import mutagen
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import base64
import sample
import numpy as np

# %%
# Replace 'YOUR_CLIENT_ID' and 'YOUR_CLIENT_SECRET' with your Spotify API credentials
client_id = '5e72cefadf2242f185811400e85ae9cf'
client_secret = '7353a65633624c60996996693beba8e5'

# Create a Spotipy client with credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
test_file_path = r'C:\Users\14089\Desktop\NILAY JAIN\Personal Projects\Play_Song_By_Mood\testing'
test_file_name = os.listdir(test_file_path)
file_name = test_file_name[2]
file_name = file_name[:file_name.index('(')]
file_name
# Out:
# 'Tootay-Makaan-Ik-Baar-Gir-Kar'

# %%
results = sp.search(q=f'track:{"Oogway Ascends"}', type='track', limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AOogway+Ascends&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#        'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#        'id': '0YC192cP3KPCRWx8zr8MfZ',
#        'name': 'Hans Zimmer',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EAHF3jdnHHdko5DBrhRUP'},
#        'href': 'https://api.spotify.com/v1/artists/3EAHF3jdnHHdko5DBrhRUP',
#        'id': '3EAHF3jdnHHdko5DBrhRUP',
#        'name': 'John Powell',
#        'type': 'artist',
#        'uri': 'spotify:artist:3EAHF3jdnHHdko5DBrhRUP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fUdfKoSrzobcPZ4bCSmJR'},
#      'href': 'https://api.spotify.com/v1/albums/2fUdfKoSrzobcPZ4bCSmJR',
#      'id': '2fUdfKoSrzobcPZ4bCSmJR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d819f77524aa7db8f1ff63d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d819f77524aa7db8f1ff63d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d819f77524aa7db8f1ff63d',
#        'width': 64}],
#      'name': 'Kung Fu Panda (Original Motion Picture Soundtrack)',
#      'release_date': '2008-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:2fUdfKoSrzobcPZ4bCSmJR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#       'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#       'id': '0YC192cP3KPCRWx8zr8MfZ',
#       'name': 'Hans Zimmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EAHF3jdnHHdko5DBrhRUP'},
#       'href': 'https://api.spotify.com/v1/artists/3EAHF3jdnHHdko5DBrhRUP',
#       'id': '3EAHF3jdnHHdko5DBrhRUP',
#       'name': 'John Powell',
#       'type': 'artist',
#       'uri': 'spotify:artist:3EAHF3jdnHHdko5DBrhRUP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 123506,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70812423'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1dZCiUTIbbvwOCALmzBh9y'},
#     'href': 'https://api.spotify.com/v1/tracks/1dZCiUTIbbvwOCALmzBh9y',
#     'id': '1dZCiUTIbbvwOCALmzBh9y',
#     'is_local': False,
#     'name': 'Oogway Ascends',
#     'popularity': 63,
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:1dZCiUTIbbvwOCALmzBh9y'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=track%3AOogway+Ascends&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 61}}

# %%
track_id = results['tracks']['items'][0]['id']
track_features = sp.audio_features(track_id)
track_features
# Out:
# [{'danceability': 0.168,
#   'energy': 0.235,
#   'key': 5,
#   'loudness': -17.462,
#   'mode': 1,
#   'speechiness': 0.0389,
#   'acousticness': 0.681,
#   'instrumentalness': 0.852,
#   'liveness': 0.089,
#   'valence': 0.0791,
#   'tempo': 109.098,
#   'type': 'audio_features',
#   'id': '1dZCiUTIbbvwOCALmzBh9y',
#   'uri': 'spotify:track:1dZCiUTIbbvwOCALmzBh9y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dZCiUTIbbvwOCALmzBh9y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dZCiUTIbbvwOCALmzBh9y',
#   'duration_ms': 123507,
#   'time_signature': 3}]

# %%
danceability = track_features[0]['danceability']
energy = track_features[0]['energy']
key = track_features[0]['key']
loudness = track_features[0]['loudness']
mode = track_features[0]['mode']
speechiness = track_features[0]['speechiness']
acousticness = track_features[0]['acousticness']
liveness = track_features[0]['liveness']
valence = track_features[0]['valence']
tempo = track_features[0]['tempo']
duration_ms = track_features[0]['duration_ms']
time_signature = track_features[0]['time_signature']

# %%
X_sample_train = np.array([danceability, acousticness, energy, liveness, valence, loudness, speechiness, tempo])
X_sample_train
# Out:
# array([ 1.68000e-01,  6.81000e-01,  2.35000e-01,  8.90000e-02,
#         7.91000e-02, -1.74620e+01,  3.89000e-02,  1.09098e+02])
